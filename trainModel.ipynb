# %% [markdown]
# ## SimpleUnet Implementation Guidance
#
# This is a step-by-step guidance of how to implement the SimpleUnet model to generate multispectral images from the RGB image. You can either run the manually run the code below or run the script with the single command line.

# %% [markdown]
# ### ✔ Run with a single command line

# %%
# python train.py --trainpath /path/to/train --valpath /path/to/val --learningrate 0.0002 --epochs 30

# %% [markdown]
# #### ✍ Run manually by explicitly listing settings

# %%
# !pip install -r requirements.txt -q
print("Installation completed.")
# Out:
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# Installation completed.

# %%
import torch
import torch.optim as optim
import torch.nn as nn
from train import train_test_model, VGGFeatureExtractor
from utils.data import load_datasets
from model import SimpleUNet
import warnings
import torch

# torch.cuda.manual_seed(42) #Fixed seed for the reproductability
warnings.filterwarnings("ignore")

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Feel free to explore other variations of models in the 'unets' directory.
model = SimpleUNet()
vgg_feature_extractor = VGGFeatureExtractor()

# Define paths and hyperparameters
train_path =  '../train/' 
val_path = '../val/'
# Out:
# Using device: cuda

# %%
learning_rate = 0.02
epochs = 2

# %%
model = SimpleUNet()
vgg_feature_extractor = VGGFeatureExtractor()
optimizer = optim.SGD(model.parameters(), lr=learning_rate,momentum=0.8)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)
train_test_model(model,train_path,val_path, optimizer, scheduler,device, epochs,0)

# %%
model = SimpleUNet()
vgg_feature_extractor = VGGFeatureExtractor()
optimizer = optim.SGD(model.parameters(), lr=learning_rate,momentum=0.8)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)
train_test_model(model,train_path,val_path, optimizer, scheduler,device, epochs,1)

# %%
model = SimpleUNet()
vgg_feature_extractor = VGGFeatureExtractor()
optimizer = optim.SGD(model.parameters(), lr=learning_rate,momentum=0.8)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)
train_test_model(model,train_path,val_path, optimizer, scheduler,device, epochs,2)
# Out:
# Best model saved with Validation LPIPS: 5.5786
# Epoch [1/2] Train PSNR: 47.1017, Val PSNR: 22.8473, Train LPIPS: 11.0232, Val LPIPS: 5.5786, Train SSIM: 0.1997, Val SSIM: 0.0621
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Best model saved with Validation LPIPS: 5.5785
# Epoch [2/2] Train PSNR: 47.1182, Val PSNR: 22.8250, Train LPIPS: 10.9811, Val LPIPS: 5.5785, Train SSIM: 0.2209, Val SSIM: 0.0770
# Train/Test completed

# %%
model = SimpleUNet()
vgg_feature_extractor = VGGFeatureExtractor()
optimizer = optim.SGD(model.parameters(), lr=learning_rate,momentum=0.8)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)
train_test_model(model,train_path,val_path, optimizer, scheduler,device, epochs,3)
# Out:
# Best model saved with Validation LPIPS: 12.6556
# Epoch [1/2] Train PSNR: 47.1354, Val PSNR: 22.7909, Train LPIPS: 21.5124, Val LPIPS: 12.6556, Train SSIM: 0.2193, Val SSIM: 0.0168

# %%
model = SimpleUNet()
vgg_feature_extractor = VGGFeatureExtractor()
optimizer = optim.SGD(model.parameters(), lr=learning_rate,momentum=0.8)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)
train_test_model(model,train_path,val_path, optimizer, scheduler,device, epochs,4)
