# %%
# !pip install -r ../requirements.txt -q
print("Installation completed.")
# Out:
# Installation completed.

# %%
import train
from train import VGGFeatureExtractor
import torch.nn as nn
from load_data import load_datasets
from unet_test import UNet, STUNet
# from unet3plus import UNet3Plus,UNet2Plus
import torch
import torch.optim as optim
import torchvision.models as models
from train import train_test_model

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
unet_model = STUNet()
vgg_feature_extractor = VGGFeatureExtractor()
    
unet_model.to(device)
vgg_feature_extractor.to(device)
epochs = 20
# Out:
# cuda

# %%
train_path = '../../train/'
val_path = '../../val/'

# %%
import torch
torch.cuda.empty_cache()

# %%
learning_rate = 0.02
# optimizer = optim.NAdam(unet_model.parameters(), lr=learning_rate)
optimizer = optim.SGD(unet_model.parameters(), lr=learning_rate,momentum=0.8)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)
train_test_model(unet_model,train_path,val_path, optimizer, scheduler,device, num_epochs=epochs)
# Out:
# /opt/conda/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:62: FutureWarning: Importing `StructuralSimilarityIndexMeasure` from `torchmetrics` was deprecated and will be removed in 2.0. Import `StructuralSimilarityIndexMeasure` from `torchmetrics.image` instead.
#   _future_warning(
# /opt/conda/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
#   return F.conv2d(input, weight, bias, self.stride,
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 5
#       3 optimizer = optim.SGD(unet_model.parameters(), lr=learning_rate,momentum=0.8)
#       4 scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)
# ...

# %%
learning_rate = 0.0002
# Adam optimizer as that in their study, an initial learning rate of 0.0005, and a momentum of 0.93
optimizer = optim.Adam(unet_model.parameters(),learning_rate)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.1)
train_test_model(unet_model,train_path,val_path, optimizer, scheduler,device, num_epochs=epochs)
# Out:
# Epoch [1/15] Train PSNR: 47.1655, Val PSNR: 22.8696, Train LPIPS: 9.4047, Val LPIPS: 6.3695, Train SSIM: 0.1062, Val SSIM: 0.0521
# Epoch [2/15] Train PSNR: 47.1656, Val PSNR: 22.8695, Train LPIPS: 9.3668, Val LPIPS: 6.3695, Train SSIM: 0.1062, Val SSIM: 0.0521
# Epoch [3/15] Train PSNR: 47.1658, Val PSNR: 22.8696, Train LPIPS: 9.5258, Val LPIPS: 6.3695, Train SSIM: 0.1062, Val SSIM: 0.0521
# Epoch [4/15] Train PSNR: 47.1659, Val PSNR: 22.8695, Train LPIPS: 9.3358, Val LPIPS: 6.3695, Train SSIM: 0.1062, Val SSIM: 0.0521
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 5
#       3 optimizer = optim.Adam(unet_model.parameters(),learning_rate)
#       4 scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.1)
# ----> 5 train_test_model(unet_model,train_path,val_path, optimizer, scheduler,device, num_epochs=epochs)
#
# ...

# %%
learning_rate = 0.002
# optimizer = optim.NAdam(unet_model.parameters(), lr=learning_rate)
optimizer = optim.SGD(unet_model.parameters(), lr=learning_rate,momentum=0.6,nesterov=True)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)
train_test_model(unet_model,train_path,val_path, optimizer, scheduler,device, num_epochs=epochs)
# Out:
# Epoch [1/15] Train PSNR: nan, Val PSNR: nan, Train LPIPS: nan, Val LPIPS: nan, Train SSIM: nan, Val SSIM: nan
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 5
#       3 optimizer = optim.SGD(unet_model.parameters(), lr=learning_rate,momentum=0.6,nesterov=True)
#       4 scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)
# ----> 5 train_test_model(unet_model,train_path,val_path, optimizer, scheduler,device, num_epochs=epochs)
#
# File ~/PSY/gsoc/ArtExtract/model/unet_train.py:64, in train_test_model(model, train_path, val_path, optimizer, scheduler, device, num_epochs, patience)
#      62 output_image = F.normalize(output_image, dim=1)
#      63 #set the alpha to 0.5
# ---> 64 loss += ms_ssim_loss(output_image, target_image)
#      65 psnr_value, lpips_value, ssim_value = metrics(output_image, target_image)
# ...

# %%
learning_rate = 0.04
optimizer = optim.Adam(unet_model.parameters(),learning_rate)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=6, gamma=0.1)
train_test_model(unet_model,train_path,val_path, optimizer, scheduler,device, num_epochs=epochs)

# %%
learning_rate = 0.02
# optimizer = optim.NAdam(unet_model.parameters(), lr=learning_rate)
optimizer = optim.SGD(unet_model.parameters(), lr=learning_rate,momentum=0.7,nesterov=True)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=50, gamma=0.1)
train_test_model(unet_model,train_path,val_path, optimizer, scheduler,device, num_epochs=200)

# %%
# find other applicable loss function on the model copies 
# run it for hundreds epochs and check the result

# %%
import gc
gc.collect()

# %%
torch.cuda.empty_cache()
